# %% [markdown]
# # Week 9
# Let's continue the analysis of the NYC Bus data. You should already have downloaded the file `mta_1706.csv`.

# %%
# Load the data from the csv file
import pandas as pd
data = pd.read_csv("mta_1706.csv", on_bad_lines='skip') # This may take some time because the file is large
data.head()
# Out:
#         RecordedAtTime  DirectionRef PublishedLineName  \
# 0  2017-06-01 00:03:34             0                B8
# 1  2017-06-01 00:03:43             1               S61
# 2  2017-06-01 00:03:49             0              Bx10
# 3  2017-06-01 00:03:31             0                Q5
# 4  2017-06-01 00:03:22             1               Bx1
#
#                   OriginName  OriginLat  OriginLong  \
# 0                 4 AV/95 ST  40.616104  -74.031143
# 1  ST GEORGE FERRY/S61 & S91  40.643169  -74.073494
# 2     E 206 ST/BAINBRIDGE AV  40.875008  -73.880142
# 3           TEARDROP/LAYOVER  40.701748  -73.802399
# 4      RIVERDALE AV/W 231 ST  40.881187  -73.909340
#
#                    DestinationName  DestinationLat  DestinationLong  \
# 0          BROWNSVILLE ROCKAWAY AV       40.656048       -73.907379
# 1                S I MALL YUKON AV       40.575935       -74.167686
# 2                 RIVERDALE 263 ST       40.912376       -73.902534
# 3    ROSEDALE LIRR STA via MERRICK       40.666012       -73.735939
# 4  MOTT HAVEN 136 ST via CONCOURSE       40.809654       -73.928360
#
#   VehicleRef  VehicleLocation.Latitude  VehicleLocation.Longitude  \
# 0   NYCT_430                 40.635170                 -73.960803
# 1  NYCT_8263                 40.590802                 -74.158340
# 2  NYCT_4223                 40.886010                 -73.912647
# 3  NYCT_8422                 40.668002                 -73.729348
# 4  NYCT_4710                 40.868134                 -73.893032
#
#              NextStopPointName ArrivalProximityText  DistanceFromStop  \
# 0            FOSTER AV/E 18 ST          approaching              76.0
# 1      MERRYMOUNT ST/TRAVIS AV          approaching              62.0
# 2  HENRY HUDSON PKY E/W 235 ST              at stop               5.0
# 3     HOOK CREEK BL/SUNRISE HY        < 1 stop away             267.0
# 4     GRAND CONCOURSE/E 196 ST              at stop              11.0
#
#    ExpectedArrivalTime ScheduledArrivalTime
# 0  2017-06-01 00:03:59             24:06:14
# 1  2017-06-01 00:03:56             23:58:02
# 2  2017-06-01 00:03:56             24:00:53
# 3  2017-06-01 00:04:03             24:03:00
# 4  2017-06-01 00:03:56             23:59:38

# %%
# The full dataset is too large. Let's only keep data on June 1st, 2017.
data['RecordedAtTime'] = pd.to_datetime(data['RecordedAtTime'])
data = data[data['RecordedAtTime'].dt.day == 1]
data = data.drop_duplicates()
print("Shape:", data.shape)
data.head()
# Out:
# Shape: (248877, 17)
#        RecordedAtTime  DirectionRef PublishedLineName  \
# 0 2017-06-01 00:03:34             0                B8
# 1 2017-06-01 00:03:43             1               S61
# 2 2017-06-01 00:03:49             0              Bx10
# 3 2017-06-01 00:03:31             0                Q5
# 4 2017-06-01 00:03:22             1               Bx1
#
#                   OriginName  OriginLat  OriginLong  \
# 0                 4 AV/95 ST  40.616104  -74.031143
# 1  ST GEORGE FERRY/S61 & S91  40.643169  -74.073494
# 2     E 206 ST/BAINBRIDGE AV  40.875008  -73.880142
# 3           TEARDROP/LAYOVER  40.701748  -73.802399
# 4      RIVERDALE AV/W 231 ST  40.881187  -73.909340
#
#                    DestinationName  DestinationLat  DestinationLong  \
# 0          BROWNSVILLE ROCKAWAY AV       40.656048       -73.907379
# 1                S I MALL YUKON AV       40.575935       -74.167686
# 2                 RIVERDALE 263 ST       40.912376       -73.902534
# 3    ROSEDALE LIRR STA via MERRICK       40.666012       -73.735939
# 4  MOTT HAVEN 136 ST via CONCOURSE       40.809654       -73.928360
#
#   VehicleRef  VehicleLocation.Latitude  VehicleLocation.Longitude  \
# 0   NYCT_430                 40.635170                 -73.960803
# 1  NYCT_8263                 40.590802                 -74.158340
# 2  NYCT_4223                 40.886010                 -73.912647
# 3  NYCT_8422                 40.668002                 -73.729348
# 4  NYCT_4710                 40.868134                 -73.893032
#
#              NextStopPointName ArrivalProximityText  DistanceFromStop  \
# 0            FOSTER AV/E 18 ST          approaching              76.0
# 1      MERRYMOUNT ST/TRAVIS AV          approaching              62.0
# 2  HENRY HUDSON PKY E/W 235 ST              at stop               5.0
# 3     HOOK CREEK BL/SUNRISE HY        < 1 stop away             267.0
# 4     GRAND CONCOURSE/E 196 ST              at stop              11.0
#
#    ExpectedArrivalTime ScheduledArrivalTime
# 0  2017-06-01 00:03:59             24:06:14
# 1  2017-06-01 00:03:56             23:58:02
# 2  2017-06-01 00:03:56             24:00:53
# 3  2017-06-01 00:04:03             24:03:00
# 4  2017-06-01 00:03:56             23:59:38

# %%
# Let's examine Bx26
Bx26 = data[data['PublishedLineName'] == 'Bx26']
print("Shape:", Bx26.shape)
Bx26.head()
# Out:
# Shape: (972, 17)
#            RecordedAtTime  DirectionRef PublishedLineName  \
# 12311 2017-06-01 05:33:52             1              Bx26
# 13282 2017-06-01 05:43:36             1              Bx26
# 14370 2017-06-01 05:53:29             1              Bx26
# 14529 2017-06-01 05:53:45             1              Bx26
# 15652 2017-06-01 06:03:23             1              Bx26
#
#                   OriginName  OriginLat  OriginLong  \
# 12311  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 13282  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 14370  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 14529  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 15652  EARHART LA/ERSKINE PL  40.861115  -73.822548
#
#                           DestinationName  DestinationLat  DestinationLong  \
# 12311  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 13282  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 14370  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 14529  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 15652  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
#
#       VehicleRef  VehicleLocation.Latitude  VehicleLocation.Longitude  \
# 12311  NYCT_4415                 40.861360                 -73.822817
# 13282  NYCT_4415                 40.867572                 -73.835474
# 14370  NYCT_4415                 40.865545                 -73.861927
# 14529  NYCT_4416                 40.869510                 -73.825654
# 15652  NYCT_4415                 40.867914                 -73.884166
#
#              NextStopPointName ArrivalProximityText  DistanceFromStop  \
# 12311     HUNTER AV/EARHART LA        < 1 stop away             216.0
# 13282     BARTOW AV/BRUNNER AV              at stop              29.0
# 14370    ALLERTON AV/BOSTON RD              at stop               0.0
# 14529  BARTOW AV/CO-OP CITY BL              at stop              19.0
# 15652  BEDFORD PK BL/MARION AV          approaching             140.0
#
#        ExpectedArrivalTime ScheduledArrivalTime
# 12311  2017-06-01 05:34:10             05:35:37
# 13282  2017-06-01 05:43:54             05:43:36
# 14370  2017-06-01 05:53:52             05:52:53
# 14529  2017-06-01 05:53:52             05:54:04
# 15652  2017-06-01 06:04:26             06:00:42

# %%
# Let's visualize the route
# Center of the map: 40.87101179741048, -73.86352516801689
import folium

bus_map = folium.Map(location=[40.87101179741048, -73.86352516801689],
           zoom_start=13)
# row = 12311
# bus_location = [Bx26.loc[row, "VehicleLocation.Latitude"],
#                 Bx26.loc[row, "VehicleLocation.Longitude"]]
# folium.Marker(bus_location, popup=row).add_to(bus_map)

# for row in Bx26.index:
#     bus_location = [Bx26.loc[row, "VehicleLocation.Latitude"],
#                     Bx26.loc[row, "VehicleLocation.Longitude"]]
#     folium.Marker(bus_location, popup=row).add_to(bus_map)
    
# Visualing the route with markers is not very beautiful. Let's use a different
# approach.
for row in Bx26.index:
    bus_location = [Bx26.loc[row, "VehicleLocation.Latitude"],
                    Bx26.loc[row, "VehicleLocation.Longitude"]]
    time = Bx26.loc[row, "RecordedAtTime"]
    folium.Circle(bus_location, radius=0.1, popup=time).add_to(bus_map)

    
bus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf576cec1c63aad9bd4aba4eb371c21d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf576cec1c63aad9bd4aba4eb371c21d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf576cec1c63aad9bd4aba4eb371c21d = L.map(
#                 &quot;map_cf576cec1c63aad9bd4aba4eb371c21d&quot;,
#                 {
#                     center: [40.87101179741048, -73.86352516801689],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f347d6e0247dc0b8c9456dcbc09bb21c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#             var circle_16e0b533eb10ec7bcf88933d046e37c4 = L.circle(
#                 [40.86136, -73.822817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#         var popup_d0eaee5b175a645550c39e1d288cf974 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36c14c73f831cc2b0a331c22df22f6fa = $(`&lt;div id=&quot;html_36c14c73f831cc2b0a331c22df22f6fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-06-01 05:33:52&lt;/div&gt;`)[0];
#                 popup_d0eaee5b175a645550c39e1d288cf974.setContent(html_36c14c73f831cc2b0a331c22df22f6fa);
#
#
#
#         circle_16e0b533eb10ec7bcf88933d046e37c4.bindPopup(popup_d0eaee5b175a645550c39e1d288cf974)
#         ;
#
#
#
#
#             var circle_18b5c8b1d30da2213969465c7dedf98b = L.circle(
#                 [40.867572, -73.835474],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#         var popup_50913a9c9d8ec7f4fd2ec7a9c74f83dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86e7bb154560dbd7f2ea01d90f29439a = $(`&lt;div id=&quot;html_86e7bb154560dbd7f2ea01d90f29439a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-06-01 05:43:36&lt;/div&gt;`)[0];
#                 popup_50913a9c9d8ec7f4fd2ec7a9c74f83dc.setContent(html_86e7bb154560dbd7f2ea01d90f29439a);
#
#
#
#         circle_18b5c8b1d30da2213969465c7dedf98b.bindPopup(popup_50913a9c9d8ec7f4fd2ec7a9c74f83dc)
#         ;
#
#
#
#
#             var circle_b4fe0f46711e52e4b10be04bff54c9f2 = L.circle(
#                 [40.865545, -73.861927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#         var popup_e1c8ab6c58e5a50fa0e3fb3df8a716ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7da334790f38632ddaa5b1fc666b2fbd = $(`&lt;div id=&quot;html_7da334790f38632ddaa5b1fc666b2fbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-06-01 05:53:29&lt;/div&gt;`)[0];
#                 popup_e1c8ab6c58e5a50fa0e3fb3df8a716ae.setContent(html_7da334790f38632ddaa5b1fc666b2fbd);
#
#
#
#         circle_b4fe0f46711e52e4b10be04bff54c9f2.bindPopup(popup_e1c8ab6c58e5a50fa0e3fb3df8a716ae)
#         ;
#
#
#
#
#             var circle_d6c3eb5eec287fa848a9b28b8afcf85e = L.circle(
#                 [40.86951, -73.825654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;

# %%
# Calculate the wating time
from datetime import datetime
location = [40.874634210385175, -73.89178270047667] # Bx26 stop at LC
time = datetime(2017, 6, 1, 12, 14, 0)
print(time)
# Out:
# 2017-06-01 12:14:00

# %%
# Find the row around this time
Bx26 = Bx26.copy()
Bx26['TimeDiff'] = time - Bx26['RecordedAtTime']
Bx26.head()
# Out:
#            RecordedAtTime  DirectionRef PublishedLineName  \
# 12311 2017-06-01 05:33:52             1              Bx26
# 13282 2017-06-01 05:43:36             1              Bx26
# 14370 2017-06-01 05:53:29             1              Bx26
# 14529 2017-06-01 05:53:45             1              Bx26
# 15652 2017-06-01 06:03:23             1              Bx26
#
#                   OriginName  OriginLat  OriginLong  \
# 12311  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 13282  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 14370  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 14529  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 15652  EARHART LA/ERSKINE PL  40.861115  -73.822548
#
#                           DestinationName  DestinationLat  DestinationLong  \
# 12311  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 13282  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 14370  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 14529  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 15652  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
#
#       VehicleRef  VehicleLocation.Latitude  VehicleLocation.Longitude  \
# 12311  NYCT_4415                 40.861360                 -73.822817
# 13282  NYCT_4415                 40.867572                 -73.835474
# 14370  NYCT_4415                 40.865545                 -73.861927
# 14529  NYCT_4416                 40.869510                 -73.825654
# 15652  NYCT_4415                 40.867914                 -73.884166
#
#              NextStopPointName ArrivalProximityText  DistanceFromStop  \
# 12311     HUNTER AV/EARHART LA        < 1 stop away             216.0
# 13282     BARTOW AV/BRUNNER AV              at stop              29.0
# 14370    ALLERTON AV/BOSTON RD              at stop               0.0
# 14529  BARTOW AV/CO-OP CITY BL              at stop              19.0
# 15652  BEDFORD PK BL/MARION AV          approaching             140.0
#
#        ExpectedArrivalTime ScheduledArrivalTime        TimeDiff
# 12311  2017-06-01 05:34:10             05:35:37 0 days 06:40:08
# 13282  2017-06-01 05:43:54             05:43:36 0 days 06:30:24
# 14370  2017-06-01 05:53:52             05:52:53 0 days 06:20:31
# 14529  2017-06-01 05:53:52             05:54:04 0 days 06:20:15
# 15652  2017-06-01 06:04:26             06:00:42 0 days 06:10:37

# %%
# Get the row that's closest to the target time
from datetime import timedelta
Bx26[Bx26['TimeDiff'] > timedelta(0)].sort_values('TimeDiff').head(3)
# Out:
#             RecordedAtTime  DirectionRef PublishedLineName        OriginName  \
# 100096 2017-06-01 12:03:54             0              Bx26  W 205 ST/PAUL AV
# 99896  2017-06-01 12:03:53             0              Bx26  W 205 ST/PAUL AV
# 100112 2017-06-01 12:03:51             0              Bx26  W 205 ST/PAUL AV
#
#         OriginLat  OriginLong                    DestinationName  \
# 100096  40.876999  -73.889854  CO-OP CITY EARHART LA via ALLERTN
# 99896   40.876999  -73.889854  CO-OP CITY EARHART LA via ALLERTN
# 100112  40.876999  -73.889854  CO-OP CITY EARHART LA via ALLERTN
#
#         DestinationLat  DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 100096       40.860828        -73.82267  NYCT_4416                 40.865517
# 99896        40.860828        -73.82267  NYCT_4415                 40.873974
# 100112       40.860828        -73.82267  NYCT_4106                 40.865849
#
#         VehicleLocation.Longitude                   NextStopPointName  \
# 100096                 -73.859921       ALLERTON AV/WILLIAMSBRIDGE RD
# 99896                  -73.890515                BEDFORD PK/JEROME AV
# 100112                 -73.823270  HUTCHINSON RVR PKY/EINSTEIN LOOP N
#
#        ArrivalProximityText  DistanceFromStop  ExpectedArrivalTime  \
# 100096          approaching              71.0  2017-06-01 12:04:31
# 99896           approaching             100.0  2017-06-01 12:04:28
# 100112          approaching              60.0  2017-06-01 12:04:03
#
#        ScheduledArrivalTime        TimeDiff
# 100096             12:01:00 0 days 00:10:06
# 99896              11:57:21 0 days 00:10:07
# 100112             12:03:28 0 days 00:10:09

# %%
df = Bx26[Bx26['TimeDiff'] <= timedelta(0)].sort_values('TimeDiff',
                        ascending=False).head(8)

# %%
for row in df.index:
    bus_location = [df.loc[row, "VehicleLocation.Latitude"],
                    df.loc[row, "VehicleLocation.Longitude"]]
    bus_ref = df.loc[row, "VehicleRef"]
    direction = df.loc[row, "DirectionRef"]
    folium.Marker(bus_location, popup=direction).add_to(bus_map)

# %%
bus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf576cec1c63aad9bd4aba4eb371c21d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf576cec1c63aad9bd4aba4eb371c21d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf576cec1c63aad9bd4aba4eb371c21d = L.map(
#                 &quot;map_cf576cec1c63aad9bd4aba4eb371c21d&quot;,
#                 {
#                     center: [40.87101179741048, -73.86352516801689],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f347d6e0247dc0b8c9456dcbc09bb21c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#             var circle_16e0b533eb10ec7bcf88933d046e37c4 = L.circle(
#                 [40.86136, -73.822817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#         var popup_d0eaee5b175a645550c39e1d288cf974 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36c14c73f831cc2b0a331c22df22f6fa = $(`&lt;div id=&quot;html_36c14c73f831cc2b0a331c22df22f6fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-06-01 05:33:52&lt;/div&gt;`)[0];
#                 popup_d0eaee5b175a645550c39e1d288cf974.setContent(html_36c14c73f831cc2b0a331c22df22f6fa);
#
#
#
#         circle_16e0b533eb10ec7bcf88933d046e37c4.bindPopup(popup_d0eaee5b175a645550c39e1d288cf974)
#         ;
#
#
#
#
#             var circle_18b5c8b1d30da2213969465c7dedf98b = L.circle(
#                 [40.867572, -73.835474],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#         var popup_50913a9c9d8ec7f4fd2ec7a9c74f83dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86e7bb154560dbd7f2ea01d90f29439a = $(`&lt;div id=&quot;html_86e7bb154560dbd7f2ea01d90f29439a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-06-01 05:43:36&lt;/div&gt;`)[0];
#                 popup_50913a9c9d8ec7f4fd2ec7a9c74f83dc.setContent(html_86e7bb154560dbd7f2ea01d90f29439a);
#
#
#
#         circle_18b5c8b1d30da2213969465c7dedf98b.bindPopup(popup_50913a9c9d8ec7f4fd2ec7a9c74f83dc)
#         ;
#
#
#
#
#             var circle_b4fe0f46711e52e4b10be04bff54c9f2 = L.circle(
#                 [40.865545, -73.861927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf576cec1c63aad9bd4aba4eb371c21d);
#
#
#         var popup_e1c8ab6c58e5a50fa0e3fb3df8a716ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7da334790f38632ddaa5b1fc666b2fbd = $(`&lt;div id=&quot;html_7da334790f38632ddaa5b1fc666b2fbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2017-06-01 05:53:29&lt;/div&gt;`)[0];
#                 popup_e1c8ab6c58e5a50fa0e3fb3df8a716ae.setContent(html_7da334790f38632ddaa5b1fc666b2fbd);
#
#
#
#         circle_b4fe0f46711e52e4b10be04bff54c9f2.bindPopup(popup_e1c8ab6c58e5a50fa0e3fb3df8a716ae)
#         ;
#
#
#
#
#             var circle_d6c3eb5eec287fa848a9b28b8afcf85e = L.circle(
#                 [40.86951, -73.825654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;

# %%
direction = 1
# How do we find the time a Bx26 comes to the LC stop?
stop_name = "BEDFORD PK/PAUL AV"
df = Bx26[(Bx26["NextStopPointName"] == stop_name) & \
          (Bx26["ArrivalProximityText"] == 'at stop')]
df.head()
# Out:
#            RecordedAtTime  DirectionRef PublishedLineName  \
# 50205 2017-06-01 08:23:54             1              Bx26
# 55450 2017-06-01 08:44:07             1              Bx26
#
#                   OriginName  OriginLat  OriginLong  \
# 50205  EARHART LA/ERSKINE PL  40.861115  -73.822548
# 55450  EARHART LA/ERSKINE PL  40.861115  -73.822548
#
#                           DestinationName  DestinationLat  DestinationLong  \
# 50205  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
# 55450  BEDFORD PK LEHMAN COLL via ALLERTN       40.877071       -73.890068
#
#       VehicleRef  VehicleLocation.Latitude  VehicleLocation.Longitude  \
# 50205  NYCT_8329                 40.874348                 -73.891349
# 55450  NYCT_4411                 40.874364                 -73.891384
#
#         NextStopPointName ArrivalProximityText  DistanceFromStop  \
# 50205  BEDFORD PK/PAUL AV              at stop              17.0
# 55450  BEDFORD PK/PAUL AV              at stop              13.0
#
#        ExpectedArrivalTime ScheduledArrivalTime        TimeDiff
# 50205  2017-06-01 08:24:01             08:14:39 0 days 03:50:06
# 55450  2017-06-01 08:44:33             08:29:39 0 days 03:29:53

# %%
# Bx26['NextStopPointName'].unique()
Bx26['ArrivalProximityText'].unique()
# Out:
# array(['< 1 stop away', 'at stop', 'approaching', '0.5 miles away',
#        '0.6 miles away', '0.7 miles away'], dtype=object)
